# %% [markdown]
# ## Imports

# %%
#we want to install requests (if not already installed) using pip install requests, done in terminal
#requests helps us get the HTML
import requests

#we want to install beautifulsoup (if not already installed) using pip install beautifulsoup4, done in terminal
#beautifulsoup helps us read the html
from bs4 import BeautifulSoup as bs

#we want to install selenium (if not already installed) using pip install selenium, done in terminal
#import selenium
from selenium import webdriver

#time for being human-like
import time

#pandas dataframe
import pandas as pd

# %% [markdown]
# ## Let's try to webscrape off one website first (aka, no selenium)
# We will first try to get just the episode titles of Gravity Falls from an IMDB page

# %%
# let's make a dataframe to store our data
column_names = ["Episode Title"]
df = pd.DataFrame(columns=column_names)
df
# Out:
# Empty DataFrame
# Columns: [Episode Title]
# Index: []

# %%
# Getting page HTML through request
gravity_falls = requests.get('https://www.imdb.com/title/tt1865718/episodes?season=1&ref_=tt_eps_sn_1')
soup = bs(gravity_falls.content, 'html.parser') # Parsing content using beautifulsoup

# %% [markdown]
# Let's try to just get our film titles first

# %%
titles = soup.find_all("a", title=True, itemprop="name")
titles
# Out:
# [<a href="/title/tt2152239/" itemprop="name" title="Tourist Trapped">Tourist Trapped</a>,
#  <a href="/title/tt2168670/" itemprop="name" title="The Legend of the Gobblewonker">The Legend of the Gobblewonker</a>,
#  <a href="/title/tt2168676/" itemprop="name" title="Headhunters">Headhunters</a>,
#  <a href="/title/tt2229194/" itemprop="name" title="The Hand That Rocks the Mabel">The Hand That Rocks the Mabel</a>,
#  <a href="/title/tt2229196/" itemprop="name" title="The Inconveniencing">The Inconveniencing</a>,
#  <a href="/title/tt2229192/" itemprop="name" title="Dipper vs. Manliness">Dipper vs. Manliness</a>,
#  <a href="/title/tt2267658/" itemprop="name" title="Double Dipper">Double Dipper</a>,
#  <a href="/title/tt2267660/" itemprop="name" title="Irrational Treasure">Irrational Treasure</a>,
#  <a href="/title/tt2310928/" itemprop="name" title="The Time Traveler's Pig">The Time Traveler's Pig</a>,
#  <a href="/title/tt2340344/" itemprop="name" title="Fight Fighters">Fight Fighters</a>,
#  <a href="/title/tt2340350/" itemprop="name" title="Little Dipper">Little Dipper</a>,
#  <a href="/title/tt2439428/" itemprop="name" title="Summerween">Summerween</a>,
#  <a href="/title/tt2468818/" itemprop="name" title="Boss Mabel">Boss Mabel</a>,
#  <a href="/title/tt2717560/" itemprop="name" title="Bottomless Pit!">Bottomless Pit!</a>,
#  <a href="/title/tt2717562/" itemprop="name" title="The Deep End">The Deep End</a>,
#  <a href="/title/tt2717564/" itemprop="name" title="Carpet Diem">Carpet Diem</a>,
#  <a href="/title/tt2813658/" itemprop="name" title="Boyz Crazy">Boyz Crazy</a>,
#  <a href="/title/tt2973488/" itemprop="name" title="Land Before Swine">Land Before Swine</a>,
#  <a href="/title/tt3031772/" itemprop="name" title="Dreamscaperers">Dreamscaperers</a>,
#  <a href="/title/tt3054596/" itemprop="name" title="Gideon Rises">Gideon Rises</a>]

# %%
for title in titles:
    print(title.get_text())
# Out:
# Tourist Trapped
# The Legend of the Gobblewonker
# Headhunters
# The Hand That Rocks the Mabel
# The Inconveniencing
# Dipper vs. Manliness
# Double Dipper
# Irrational Treasure
# The Time Traveler's Pig
# Fight Fighters
# Little Dipper
# Summerween
# Boss Mabel
# Bottomless Pit!
# The Deep End
# Carpet Diem
# Boyz Crazy
# Land Before Swine
# Dreamscaperers
# Gideon Rises

# %% [markdown]
# let's add to a list to add this information to our dataframe

# %%
episode_titles = []
for title in titles:
    episode_titles.append(title.get_text())
df["Episode Title"] = episode_titles
df
# Out:
#                      Episode Title
# 0                  Tourist Trapped
# 1   The Legend of the Gobblewonker
# 2                      Headhunters
# 3    The Hand That Rocks the Mabel
# 4              The Inconveniencing
# 5             Dipper vs. Manliness
# 6                    Double Dipper
# 7              Irrational Treasure
# 8          The Time Traveler's Pig
# 9                   Fight Fighters
# 10                   Little Dipper
# 11                      Summerween
# 12                      Boss Mabel
# 13                 Bottomless Pit!
# 14                    The Deep End
# 15                     Carpet Diem
# 16                      Boyz Crazy
# 17               Land Before Swine
# 18                  Dreamscaperers
# 19                    Gideon Rises

# %% [markdown]
# Let's try to get our episode dates now.

# %%
dates = soup.find_all(class_="airdate")
dates
# Out:
# [<div class="airdate">
#              15 Jun. 2012
#      </div>,
#  <div class="airdate">
#              29 Jun. 2012
#      </div>,
#  <div class="airdate">
#              30 Jun. 2012
#      </div>,
#  <div class="airdate">
#              6 Jul. 2012
#      </div>,
#  <div class="airdate">
#              13 Jul. 2012
#      </div>,
#  <div class="airdate">
#              20 Jul. 2012
#      </div>,
#  <div class="airdate">
#              10 Aug. 2012
#      </div>,
#  <div class="airdate">
#              17 Aug. 2012
#      </div>,
#  <div class="airdate">
#              24 Aug. 2012
#      </div>,
#  <div class="airdate">
#              14 Sep. 2012
#      </div>,
#  <div class="airdate">
#              28 Sep. 2012
#      </div>,
#  <div class="airdate">
#              5 Oct. 2012
#      </div>,
#  <div class="airdate">
#              15 Feb. 2013
#      </div>,
#  <div class="airdate">
#              1 Mar. 2013
#      </div>,
#  <div class="airdate">
#              15 Mar. 2013
#      </div>,
#  <div class="airdate">
#              5 Apr. 2013
#      </div>,
#  <div class="airdate">
#              19 Apr. 2013
#      </div>,
#  <div class="airdate">
#              28 Jun. 2013
#      </div>,
#  <div class="airdate">
#              12 Jul. 2013
#      </div>,
#  <div class="airdate">
#              2 Aug. 2013
#      </div>]

# %%
for date in dates:
    print(date.get_text().strip())
# Out:
# 15 Jun. 2012
# 29 Jun. 2012
# 30 Jun. 2012
# 6 Jul. 2012
# 13 Jul. 2012
# 20 Jul. 2012
# 10 Aug. 2012
# 17 Aug. 2012
# 24 Aug. 2012
# 14 Sep. 2012
# 28 Sep. 2012
# 5 Oct. 2012
# 15 Feb. 2013
# 1 Mar. 2013
# 15 Mar. 2013
# 5 Apr. 2013
# 19 Apr. 2013
# 28 Jun. 2013
# 12 Jul. 2013
# 2 Aug. 2013

# %% [markdown]
# Great! Let's add this to our dataframe

# %%
episode_dates = []
for date in dates:
    episode_dates.append(date.get_text().strip())
df["Air Date"] = episode_dates
df["Air Date"] = df["Air Date"].astype('datetime64[ns]') #convert String to datetime cuz why not
df
# Out:
#                      Episode Title   Air Date
# 0                  Tourist Trapped 2012-06-15
# 1   The Legend of the Gobblewonker 2012-06-29
# 2                      Headhunters 2012-06-30
# 3    The Hand That Rocks the Mabel 2012-07-06
# 4              The Inconveniencing 2012-07-13
# 5             Dipper vs. Manliness 2012-07-20
# 6                    Double Dipper 2012-08-10
# 7              Irrational Treasure 2012-08-17
# 8          The Time Traveler's Pig 2012-08-24
# 9                   Fight Fighters 2012-09-14
# 10                   Little Dipper 2012-09-28
# 11                      Summerween 2012-10-05
# 12                      Boss Mabel 2013-02-15
# 13                 Bottomless Pit! 2013-03-01
# 14                    The Deep End 2013-03-15
# 15                     Carpet Diem 2013-04-05
# 16                      Boyz Crazy 2013-04-19
# 17               Land Before Swine 2013-06-28
# 18                  Dreamscaperers 2013-07-12
# 19                    Gideon Rises 2013-08-02

# %% [markdown]
# ## Let's try to incorporate Selenium into our program now
# We want to automate our program such that it clicks the hyperlink of each movie and gets information about its box office

# %%
# set up webdriver, specifically chromedriver
home_list = 'https://www.imdb.com/title/tt1865718/episodes?season=1&ref_=tt_eps_sn_1'

driver = webdriver.Chrome(executable_path='Downloads/chromedriver')
driver.get(home_list)

#we should get a pop up chrome tab
# Out:
# /var/folders/hh/x8w4xwts0t14ql5mw_bq2x_00000gn/T/ipykernel_1549/5081462.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='Downloads/chromedriver')

# %%
http = "https://www.imdb.com/"
# we will add the href onto the end of the http string
hrefs = []
for title in titles:
    hrefs.append(title.get('href'))

i=0
while i < len(df["Episode Title"]):
    url = http + hrefs[i]
    driver.get(url)
    episode_soup = bs(driver.page_source, 'html.parser')
    i += 1
    time.sleep(5)

# %% [markdown]
# Great! We can now go from hyperlink to hyperlink. Now, let's scrape each website's box office data

# %%
http = "https://www.imdb.com/"
# we will add the href onto the end of the http string
hrefs = []
for title in titles:
    hrefs.append(title.get('href'))

i=0
synopses = []
while i < len(df["Episode Title"]):
    url = http + hrefs[i]
    driver.get(url)
    episode_soup = bs(driver.page_source, 'html.parser')
    synopsis = episode_soup.find(class_="sc-16ede01-2 gXUyNh").get_text()
    synopses.append(synopsis)
    i += 1
    time.sleep(5)

# %%
# add to dataframe
df["Synopsis"] = synopses

# %%
df
# Out:
#                      Episode Title   Air Date  \
# 0                  Tourist Trapped 2012-06-15
# 1   The Legend of the Gobblewonker 2012-06-29
# 2                      Headhunters 2012-06-30
# 3    The Hand That Rocks the Mabel 2012-07-06
# 4              The Inconveniencing 2012-07-13
# 5             Dipper vs. Manliness 2012-07-20
# 6                    Double Dipper 2012-08-10
# 7              Irrational Treasure 2012-08-17
# 8          The Time Traveler's Pig 2012-08-24
# 9                   Fight Fighters 2012-09-14
# 10                   Little Dipper 2012-09-28
# 11                      Summerween 2012-10-05
# 12                      Boss Mabel 2013-02-15
# 13                 Bottomless Pit! 2013-03-01
# 14                    The Deep End 2013-03-15
# 15                     Carpet Diem 2013-04-05
# 16                      Boyz Crazy 2013-04-19
# 17               Land Before Swine 2013-06-28
# 18                  Dreamscaperers 2013-07-12
# 19                    Gideon Rises 2013-08-02
#
#                                              Synopsis
# 0   After finding a strange book in the forest, Di...
# 1   Dipper and Mabel hear rumours that a sea monst...
# 2   The kids discover Stan's collection of wax scu...
# 3   Dipper and Mabel meet an intriguing new neighb...
# 4   Dipper tries to impress Wendy by going along w...
# 5   In order to become more manly, Dipper seeks th...
# 6   Stan throws a big party to promote the Mystery...
# 7   During Gravity Falls' Pioneer Day celebration,...
# 8   Dipper ruins a chance to impress Wendy at a fa...
# 9   Dipper brings a video game character, Rumble M...
# 10  Dipper finds a magic crystal with the ability ...
# 11  It's Summerween, and Dipper and Mabel are visi...
# 12  Mabel is in charge of the Mystery Shack after ...
# 13  Dipper, Mabel, Stan, and Soos accidentally fal...
# 14  It's the hottest day of the Summer and the ope...
# 15  Dipper wants his own room and when Soos finds ...
# 16  When Mabel Discovers that her favourite boy ba...
# 17  A dinosaur loose in Gravity Falls snatches up ...
# 18  Dipper, Mabel and Soos go through Stan's mind ...
# 19  When Lil' Gideon takes over the Shack, Dipper ...
